# %% [markdown]
# Hello and welcome to the WorldCover Preprocessing Notebook!

# %% [markdown]
# Create a python envionment with the Version 3.10:
# i.E. :
# conda create -n WC python=3.10
# activate with:
# conda activate WorldCover
# conda install -c conda-forge rasterio geopandas shapely fiona pyproj gdal

# %% [markdown]
# load the border file using geopandas and check its CRS

# %%
# define data paths for data files
DATA_PATH = "../../../../data"
WORLDCOVER_PATH = DATA_PATH + "/preprocessing/worldcover/2021"

# %%
# Change to your environment variables for PROJ and GDAL to ensure proper functioning of geospatial libraries.
import os
os.environ["PROJ_LIB"] = r"C:\Users\alexa\anaconda3\envs\WC\Library\share\proj"
os.environ["GDAL_DATA"] = r"C:\Users\alexa\anaconda3\envs\WC\Library\share\gdal"

import geopandas as gpd
import rasterio

# %%
import geopandas as gpd
# Replace with your actual file path and layer name if necessary
gpkg_path = DATA_PATH  + "/base/swissBOUNDARIES3D/swissBOUNDARIES3D_1_5_LV95_LN02.gpkg"
border_gdf = gpd.read_file(gpkg_path, layer="tlm_landesgebiet")
print(border_gdf.crs)  # Check the CRS
# Out:
# c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\pyogrio\core.py:35: RuntimeWarning: Could not detect GDAL data files. Set GDAL_DATA environment variable to the correct path.
#   _init_gdal_data()
# c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\pyogrio\geopandas.py:275: UserWarning: More than one layer found in 'swissBOUNDARIES3D_1_5_LV95_LN02.gpkg': 'tlm_hoheitsgrenze' (default), 'tlm_hoheitsgebiet', 'tlm_bezirksgebiet', 'tlm_landesgebiet', 'tlm_kantonsgebiet'. Specify layer parameter to avoid this warning.
#   result = read_func(
# EPSG:2056

# %% [markdown]
# Crate a buffer of 1 kilometers around the border

# %%
buffered_border_gdf = border_gdf.copy()
buffered_border_gdf["geometry"] = buffered_border_gdf.buffer(1000)

# %% [markdown]
# fill the holes in the border geometry (optional)

# %%
from shapely.geometry import Polygon, MultiPolygon

def fill_all_holes(geom):
    return Polygon(geom.exterior) if geom.type == 'Polygon' else MultiPolygon([Polygon(g.exterior) for g in geom.geoms])

buffered_border_gdf["geometry"] = buffered_border_gdf.geometry.apply(fill_all_holes)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_14420\323703650.py:4: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   return Polygon(geom.exterior) if geom.type == 'Polygon' else MultiPolygon([Polygon(g.exterior) for g in geom.geoms])

# %% [markdown]
# Save the buffered geopackage

# %%
buffered_border_gdf.to_file(WORLDCOVER_PATH  + "/swiss_border_buffered_1km.gpkg", driver="GPKG")

# %% [markdown]
# load the raster files

# %%
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob

# Replace this with your actual folder containing the 3 WorldCover rasters
raster_folder = WORLDCOVER_PATH  + "/tiles/"

# List all .tif files in the folder
raster_files = glob.glob(raster_folder + "*.tif") #

# Verify that three tiles were found
print(raster_files)
# Out:
# ['../../../data/preprocessing/worldcover/2021/tiles\\ESA_WorldCover_10m_2021_V200_N45E003_Map.tif', '../../../data/preprocessing/worldcover/2021/tiles\\ESA_WorldCover_10m_2021_V200_N45E006_Map.tif', '../../../data/preprocessing/worldcover/2021/tiles\\ESA_WorldCover_10m_2021_V200_N45E009_Map.tif']

# %% [markdown]
# open and merge the raster files

# %%
src_files_to_mosaic = [rasterio.open(fp) for fp in raster_files]
mosaic, mosaic_transform = merge(src_files_to_mosaic)

# %% [markdown]
# Copy metadata from one source raster

# %%
out_meta = src_files_to_mosaic[0].meta.copy()
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": mosaic_transform,
    "crs": src_files_to_mosaic[0].crs
})

# %% [markdown]
# Save the merged raster

# %%
# Save as GeoTIFF (still in EPSG:4326)
out_fp = WORLDCOVER_PATH+"/worldcover_2021_merged.tif"
with rasterio.open(out_fp, "w", **out_meta) as dest:
    dest.write(mosaic)

# %% [markdown]
# change the CRS of the merged raster to EPSG:2056

# %%
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling

# %% [markdown]
# define input and output files

# %%
# Input: merged raster still in EPSG:4326
src_fp = WORLDCOVER_PATH+"/worldcover_2021_merged.tif"

# Output: reprojected raster
dst_fp = WORLDCOVER_PATH+"/worldcover_2021_merged_epsg2056.tif"

# %% [markdown]
# Open the source raster and perform the reprojection.
# This might take a while depending on the size of the raster and your computer performance

# %%
with rasterio.open(src_fp) as src:
    transform, width, height = calculate_default_transform(
        src.crs, "EPSG:2056", src.width, src.height, *src.bounds
    )

    kwargs = src.meta.copy()
    kwargs.update({
        "crs": "EPSG:2056",
        "transform": transform,
        "width": width,
        "height": height
    })

    with rasterio.open(dst_fp, "w", **kwargs) as dst:
        for i in range(1, src.count + 1):
            reproject(
                source=rasterio.band(src, i),
                destination=rasterio.band(dst, i),
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs="EPSG:2056",
                resampling=Resampling.nearest  # keep categorical values intact
            )

# %% [markdown]
# Verify if the transformation was sucessful by checking the CRS

# %%
with rasterio.open(dst_fp) as r:
    print(r.crs)
    print(r.count, r.width, r.height)
# Out:
# EPSG:2056
# 1 105382 51000

# %% [markdown]
# load merged and transformed raster and geopakage with the buffered border

# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask

# Paths
raster_path = WORLDCOVER_PATH + "/worldcover_2021_merged_epsg2056.tif"
mask_path = WORLDCOVER_PATH  + "/swiss_border_buffered_1km.gpkg"

# Read buffered border
mask_gdf = gpd.read_file(mask_path)
print(mask_gdf.crs)
# Out:
# EPSG:2056

# %% [markdown]
#  Convert mask geometries

# %%
mask_geom = [mask_gdf.union_all()]  # Combine if multiple polygons

# %% [markdown]
# Clip (mask) the raster

# %%
with rasterio.open(raster_path) as src:
    clipped_array, clipped_transform = mask(
        dataset=src,
        shapes=mask_geom,
        crop=True,
        nodata=0
    )
    clipped_meta = src.meta.copy()

clipped_meta.update({
    "driver": "GTiff",
    "height": clipped_array.shape[1],
    "width": clipped_array.shape[2],
    "transform": clipped_transform,
})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 with rasterio.open(raster_path) as src:
# ----> 2     clipped_array, clipped_transform = mask(
#       3         dataset=src,
#       4         shapes=mask_geom,
#       5         crop=True,
#       6         nodata=0
#       7     )
#       8     clipped_meta = src.meta.copy()
#      10 clipped_meta.update({
#      11     "driver": "GTiff",
#      12     "height": clipped_array.shape[1],
#      13     "width": clipped_array.shape[2],
#      14     "transform": clipped_transform,
#      15 })
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\mask.py:180, in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     177     else:
#     178         nodata = 0
# --> 180 shape_mask, transform, window = raster_geometry_mask(
#     181     dataset, shapes, all_touched=all_touched, invert=invert, crop=crop,
#     182     pad=pad, pad_width=pad_width)
#     184 if indexes is None:
#     185     out_shape = (dataset.count, ) + shape_mask.shape
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\mask.py:106, in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#     103     transform = dataset.transform
#     104     out_shape = (int(dataset.height), int(dataset.width))
# --> 106 mask = geometry_mask(shapes, transform=transform, invert=invert,
#     107                      out_shape=out_shape, all_touched=all_touched)
#     109 return mask, transform, window
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\env.py:410, in ensure_env.<locals>.wrapper(*args, **kwds)
#     407 @wraps(f)
#     408 def wrapper(*args, **kwds):
#     409     if local._env:
# --> 410         return f(*args, **kwds)
#     411     else:
#     412         with Env.from_defaults():
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\features.py:69, in geometry_mask(geometries, out_shape, transform, all_touched, invert)
#      34 """Create a mask from shapes.
#      35
#      36 By default, mask is intended for use as a
#    (...)
#      65
#      66 """
#      67 fill, mask_value = (0, 1) if invert else (1, 0)
# ---> 69 return rasterize(
#      70     geometries,
#      71     out_shape=out_shape,
#      72     transform=transform,
#      73     all_touched=all_touched,
#      74     fill=fill,
#      75     default_value=mask_value).astype('bool')
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\env.py:410, in ensure_env.<locals>.wrapper(*args, **kwds)
#     407 @wraps(f)
#     408 def wrapper(*args, **kwds):
#     409     if local._env:
# --> 410         return f(*args, **kwds)
#     411     else:
#     412         with Env.from_defaults():
#
# File c:\Users\jonas\anaconda3\envs\worldcover\lib\site-packages\rasterio\features.py:380, in rasterize(shapes, out_shape, fill, nodata, masked, out, transform, all_touched, merge_alg, default_value, dtype, skip_invalid, dst_path, dst_kwds)
#     378     if len(out_shape) != 2:
#     379         raise ValueError('Invalid out_shape, must be 2D')
# --> 380     out = np.empty(out_shape, dtype=dtype)
#     381     out.fill(fill)
#     383 else:
#
# MemoryError: Unable to allocate 12.8 GiB for an array with shape (33071, 52050) and data type int64

# %% [markdown]
# Save the clipped raster

# %%
out_path = WORLDCOVER_PATH + "/worldcover_2021_clipped.tif"
with rasterio.open(out_path, "w", **clipped_meta) as dest:
    dest.write(clipped_array)

# %% [markdown]
# Now you should have a clipped raster of WorldCover 2021 for Switzerland with a 1km buffer around the border! If that is not the case feel free to reach out to my email: alexander.ruehli@students.fhnw.ch so we can cry about it together :)
